# %%
import json
import os
import glob
import pandas as pd
import numpy as np

# %%
def get_files(filepath):
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root,"*json"))
        for f in files:
            all_files.append(os.path.abspath(f))
    return all_files

# %%
beacon_data = get_files("json_datas")
filepath = beacon_data[0]

# %%
df = pd.read_json(filepath, lines = True)
print(df.head())
# Out:
#                                           pointModel  \
# 0  {'indoorLevel': 0, 'lat': 36.89817711035454, '...
#
#                                       beaconDataList
# 0  [{'name': 'null', 'uuid': '383e5cf9-6c79-4e7b-...

# %%
data_list = []
for data in beacon_data:
    with open(data) as doc:
        exp = json.load(doc)
        data_list.append(exp)

# %%
print(data_list[:5])
# Out:
# [{'pointModel': {'indoorLevel': 0, 'lat': 36.89817711035454, 'long': 30.647500580636038}, 'beaconDataList': [{'name': 'null', 'uuid': '383e5cf9-6c79-4e7b-902d-f6a8743d178f', 'macAddress': 'A0:E6:F8:40:28:E8', 'major': 1000, 'minor': 1056, 'distance': 0.7, 'proximity': 'Near', 'rssi': -56, 'txPower': -60, 'scanTime': '18 March 2022 02:32:07 PM'}, {'name': 'null', 'uuid': 'a849c1ed-ad3c-4e8f-a571-089dae67cccc', 'macAddress': 'A0:E6:F8:2C:1C:D6', 'major': 1000, 'minor': 1149, 'distance': 2.17, 'proximity': 'Near', 'rssi': -71, 'txPower': -60, 'scanTime': '18 March 2022 02:32:07 PM'}, {'name': 'null', 'uuid': 'edae28d6-489b-446c-af10-6663fb553136', 'macAddress': 'A0:E6:F8:40:3B:86', 'major': 1000, 'minor': 1027, 'distance': 1.07, 'proximity': 'Near', 'rssi': -61, 'txPower': -60, 'scanTime': '18 March 2022 02:32:07 PM'}, {'name': 'null', 'uuid': 'a849c1ed-ad3c-4e8f-a571-089dae67cccc', 'macAddress': 'A0:E6:F8:3F:D9:29', 'major': 1000, 'minor': 1143, 'distance': 0.98, 'proximity': 'Near', '
# ...

# %%
df2 = pd.DataFrame(data_list)
df2.head()
# Out:
#                                           pointModel  \
# 0  {'indoorLevel': 0, 'lat': 36.89817711035454, '...
# 1  {'indoorLevel': 0, 'lat': 36.8982103360834, 'l...
# 2  {'indoorLevel': 0, 'lat': 36.89836681844261, '...
# 3  {'indoorLevel': 0, 'lat': 36.898675495357885, ...
# 4  {'indoorLevel': 0, 'lat': 36.89868942863619, '...
#
#                                       beaconDataList
# 0  [{'name': 'null', 'uuid': '383e5cf9-6c79-4e7b-...
# 1  [{'name': 'null', 'uuid': '383e5cf9-6c79-4e7b-...
# 2  [{'name': 'null', 'uuid': '383e5cf9-6c79-4e7b-...
# 3  [{'name': 'null', 'uuid': '383e5cf9-6c79-4e7b-...
# 4  [{'name': 'null', 'uuid': '383e5cf9-6c79-4e7b-...

# %%
df2.iloc[:5].to_json("df2_indent.json",orient = "records",indent = 5)

# %%
df3 = pd.read_json("df2_indent.json")
df3.head()
# Out:
#                                           pointModel  \
# 0  {'indoorLevel': 0, 'lat': 36.8981771104, 'long...
# 1  {'indoorLevel': 0, 'lat': 36.8982103361, 'long...
# 2  {'indoorLevel': 0, 'lat': 36.8983668184, 'long...
# 3  {'indoorLevel': 0, 'lat': 36.8986754954, 'long...
# 4  {'indoorLevel': 0, 'lat': 36.8986894286, 'long...
#
#                                       beaconDataList
# 0  [{'name': 'null', 'uuid': '383e5cf9-6c79-4e7b-...
# 1  [{'name': 'null', 'uuid': '383e5cf9-6c79-4e7b-...
# 2  [{'name': 'null', 'uuid': '383e5cf9-6c79-4e7b-...
# 3  [{'name': 'null', 'uuid': '383e5cf9-6c79-4e7b-...
# 4  [{'name': 'null', 'uuid': '383e5cf9-6c79-4e7b-...

# %%
print(df2["beaconDataList"])
# Out:
# 0    [{'name': 'null', 'uuid': '383e5cf9-6c79-4e7b-...
# 1    [{'name': 'null', 'uuid': '383e5cf9-6c79-4e7b-...
# 2    [{'name': 'null', 'uuid': '383e5cf9-6c79-4e7b-...
# 3    [{'name': 'null', 'uuid': '383e5cf9-6c79-4e7b-...
# 4    [{'name': 'null', 'uuid': '383e5cf9-6c79-4e7b-...
# Name: beaconDataList, dtype: object

# %%
rssi = df2.iloc[:1].values
print(rssi)
# Out:
# [[{'indoorLevel': 0, 'lat': 36.89817711035454, 'long': 30.647500580636038}
# ...

# %%
print(type(rssi))
# Out:
# <class 'numpy.ndarray'>

# %%
print(type(df2))
# Out:
# <class 'pandas.core.frame.DataFrame'>
